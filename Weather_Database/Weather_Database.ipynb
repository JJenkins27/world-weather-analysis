# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
import sys  
sys.path.insert(0, '../')

import config
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rapid valley
# Processing Record 2 of Set 1 | makhachkala
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | imbituba
# Processing Record 5 of Set 1 | zelenets
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | hualmay
# Processing Record 8 of Set 1 | comodoro rivadavia
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | hall
# Processing Record 11 of Set 1 | airai
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | nyimba
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 1 | hayden
# Processing Record 18 of Set 1 | ponta do sol
# Processing Record 19 of Set 1 | coihaique
# Processing Record 20 of Set 1 | goderich
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | fereydunshahr
# Processing Record 23 of Set 1 | komsomolskiy
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | talas
# Processing Record 26 of Set 1 | khilok
# Processing Record 27 of Set 1 | ouesso
# Processing Record 28 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 29 of Set 1 | tshikapa
# Processing Record 30 of Set 1 | vestmannaeyjar
# Processing Record 31 of Set 1 | iqaluit
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | yulara
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | fukue
# Processing Record 38 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 1 | morondava
# Processing Record 41 of Set 1 | zaragoza
# Processing Record 42 of Set 1 | bakel
# Processing Record 43 of Set 1 | sao filipe
# Processing Record 44 of Set 1 | divo
# Processing Record 45 of Set 1 | lorengau
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | rawson
# Processing Record 48 of Set 1 | biabas
# Processing Record 49 of Set 1 | saravan
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | elizabeth city
# Processing Record 3 of Set 2 | yumen
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | north platte
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | san juan
# Processing Record 8 of Set 2 | faanui
# Processing Record 9 of Set 2 | mumford
# Processing Record 10 of Set 2 | naliya
# Processing Record 11 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 2 | alubijid
# Processing Record 13 of Set 2 | husavik
# Processing Record 14 of Set 2 | aksu
# Processing Record 15 of Set 2 | carutapera
# Processing Record 16 of Set 2 | fare
# Processing Record 17 of Set 2 | khatanga
# Processing Record 18 of Set 2 | pevek
# Processing Record 19 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | hobart
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | ibra
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | cidreira
# Processing Record 26 of Set 2 | celestun
# Processing Record 27 of Set 2 | nikolskoye
# Processing Record 28 of Set 2 | nanortalik
# Processing Record 29 of Set 2 | portland
# Processing Record 30 of Set 2 | ust-karsk
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | homer
# Processing Record 33 of Set 2 | jahrom
# City not found. Skipping...
# Processing Record 34 of Set 2 | lincoln
# Processing Record 35 of Set 2 | loralai
# Processing Record 36 of Set 2 | dubbo
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 2 | khomeynishahr
# City not found. Skipping...
# Processing Record 40 of Set 2 | coquimbo
# Processing Record 41 of Set 2 | brae
# Processing Record 42 of Set 2 | hambantota
# Processing Record 43 of Set 2 | bereda
# Processing Record 44 of Set 2 | pedernales
# Processing Record 45 of Set 2 | san patricio
# Processing Record 46 of Set 2 | leningradskiy
# Processing Record 47 of Set 2 | qaanaaq
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | kaeo
# Processing Record 50 of Set 2 | pasighat
# Processing Record 1 of Set 3 | pangnirtung
# Processing Record 2 of Set 3 | kutum
# Processing Record 3 of Set 3 | jadu
# Processing Record 4 of Set 3 | vaini
# Processing Record 5 of Set 3 | hervey bay
# Processing Record 6 of Set 3 | singuilucan
# Processing Record 7 of Set 3 | mataura
# Processing Record 8 of Set 3 | rocha
# Processing Record 9 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 3 | kruisfontein
# Processing Record 11 of Set 3 | lompoc
# Processing Record 12 of Set 3 | zhuhai
# Processing Record 13 of Set 3 | adrar
# Processing Record 14 of Set 3 | port lincoln
# Processing Record 15 of Set 3 | bowen
# Processing Record 16 of Set 3 | faya
# Processing Record 17 of Set 3 | mayo
# Processing Record 18 of Set 3 | longyearbyen
# Processing Record 19 of Set 3 | umm durman
# City not found. Skipping...
# Processing Record 20 of Set 3 | penzance
# Processing Record 21 of Set 3 | shelburne
# Processing Record 22 of Set 3 | severo-kurilsk
# Processing Record 23 of Set 3 | ballina
# Processing Record 24 of Set 3 | wanning
# Processing Record 25 of Set 3 | puerto quijarro
# Processing Record 26 of Set 3 | kasama
# Processing Record 27 of Set 3 | ilulissat
# Processing Record 28 of Set 3 | esperance
# Processing Record 29 of Set 3 | jamestown
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | fortuna
# Processing Record 32 of Set 3 | varhaug
# Processing Record 33 of Set 3 | dromolaxia
# Processing Record 34 of Set 3 | novyy urengoy
# Processing Record 35 of Set 3 | avarua
# Processing Record 36 of Set 3 | vardo
# Processing Record 37 of Set 3 | juba
# Processing Record 38 of Set 3 | behshahr
# Processing Record 39 of Set 3 | new norfolk
# Processing Record 40 of Set 3 | abalak
# Processing Record 41 of Set 3 | taltal
# Processing Record 42 of Set 3 | correntina
# Processing Record 43 of Set 3 | katobu
# Processing Record 44 of Set 3 | mocuba
# Processing Record 45 of Set 3 | bengkulu
# Processing Record 46 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 3 | tartki
# City not found. Skipping...
# Processing Record 48 of Set 3 | kropotkin
# Processing Record 49 of Set 3 | rio gallegos
# Processing Record 50 of Set 3 | lasa
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | pimentel
# Processing Record 3 of Set 4 | vestbygda
# City not found. Skipping...
# Processing Record 4 of Set 4 | carnarvon
# Processing Record 5 of Set 4 | bilibino
# Processing Record 6 of Set 4 | ust-maya
# Processing Record 7 of Set 4 | sao joao da barra
# Processing Record 8 of Set 4 | tiksi
# Processing Record 9 of Set 4 | chopovychi
# Processing Record 10 of Set 4 | port blair
# Processing Record 11 of Set 4 | souillac
# Processing Record 12 of Set 4 | hamilton
# Processing Record 13 of Set 4 | garden city
# Processing Record 14 of Set 4 | gwanda
# Processing Record 15 of Set 4 | orizona
# Processing Record 16 of Set 4 | bethel
# Processing Record 17 of Set 4 | pisco
# Processing Record 18 of Set 4 | fauske
# Processing Record 19 of Set 4 | tagusao
# Processing Record 20 of Set 4 | college
# Processing Record 21 of Set 4 | itaituba
# Processing Record 22 of Set 4 | saint-joseph
# Processing Record 23 of Set 4 | trelew
# Processing Record 24 of Set 4 | santa isabel do rio negro
# Processing Record 25 of Set 4 | lebu
# Processing Record 26 of Set 4 | san cristobal
# Processing Record 27 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 4 | tres arroyos
# Processing Record 29 of Set 4 | wewak
# Processing Record 30 of Set 4 | khuzhir
# Processing Record 31 of Set 4 | saint-medard-en-jalles
# Processing Record 32 of Set 4 | duz
# City not found. Skipping...
# Processing Record 33 of Set 4 | bambous virieux
# Processing Record 34 of Set 4 | bilimbay
# Processing Record 35 of Set 4 | valdivia
# Processing Record 36 of Set 4 | sidi ali
# Processing Record 37 of Set 4 | mount gambier
# Processing Record 38 of Set 4 | plouzane
# Processing Record 39 of Set 4 | georgetown
# Processing Record 40 of Set 4 | te anau
# Processing Record 41 of Set 4 | aleksandrov gay
# Processing Record 42 of Set 4 | sitka
# Processing Record 43 of Set 4 | graulhet
# Processing Record 44 of Set 4 | buraydah
# Processing Record 45 of Set 4 | norman wells
# Processing Record 46 of Set 4 | barrow
# Processing Record 47 of Set 4 | waverley
# Processing Record 48 of Set 4 | puerto escondido
# Processing Record 49 of Set 4 | clyde river
# Processing Record 50 of Set 4 | berdigestyakh
# Processing Record 1 of Set 5 | codrington
# Processing Record 2 of Set 5 | maceio
# Processing Record 3 of Set 5 | naze
# Processing Record 4 of Set 5 | bela
# Processing Record 5 of Set 5 | charters towers
# Processing Record 6 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 7 of Set 5 | vila franca do campo
# Processing Record 8 of Set 5 | dikson
# Processing Record 9 of Set 5 | mecca
# Processing Record 10 of Set 5 | cabo san lucas
# Processing Record 11 of Set 5 | abu samrah
# Processing Record 12 of Set 5 | sayyan
# Processing Record 13 of Set 5 | savannah bight
# Processing Record 14 of Set 5 | san jose
# Processing Record 15 of Set 5 | borama
# City not found. Skipping...
# Processing Record 16 of Set 5 | kindu
# Processing Record 17 of Set 5 | mettur
# Processing Record 18 of Set 5 | goma
# Processing Record 19 of Set 5 | muroto
# Processing Record 20 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 5 | guerrero negro
# Processing Record 22 of Set 5 | kailua
# Processing Record 23 of Set 5 | roebourne
# Processing Record 24 of Set 5 | half moon bay
# Processing Record 25 of Set 5 | hongjiang
# Processing Record 26 of Set 5 | christchurch
# Processing Record 27 of Set 5 | moose factory
# Processing Record 28 of Set 5 | grindavik
# Processing Record 29 of Set 5 | oshnaviyeh
# Processing Record 30 of Set 5 | hami
# Processing Record 31 of Set 5 | geraldton
# Processing Record 32 of Set 5 | buchmany
# Processing Record 33 of Set 5 | burewala
# Processing Record 34 of Set 5 | cherskiy
# Processing Record 35 of Set 5 | olinda
# Processing Record 36 of Set 5 | maningrida
# Processing Record 37 of Set 5 | mizdah
# Processing Record 38 of Set 5 | byron bay
# Processing Record 39 of Set 5 | les herbiers
# Processing Record 40 of Set 5 | arraial do cabo
# Processing Record 41 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 5 | henties bay
# Processing Record 43 of Set 5 | reconquista
# Processing Record 44 of Set 5 | batsfjord
# Processing Record 45 of Set 5 | praia da vitoria
# Processing Record 46 of Set 5 | batemans bay
# Processing Record 47 of Set 5 | tsogni
# Processing Record 48 of Set 5 | bethanien
# Processing Record 49 of Set 5 | westport
# Processing Record 50 of Set 5 | salto
# Processing Record 1 of Set 6 | isangel
# Processing Record 2 of Set 6 | gamba
# Processing Record 3 of Set 6 | butaritari
# Processing Record 4 of Set 6 | lac du bonnet
# Processing Record 5 of Set 6 | smolenka
# Processing Record 6 of Set 6 | antsohihy
# Processing Record 7 of Set 6 | bubaque
# Processing Record 8 of Set 6 | viseu
# Processing Record 9 of Set 6 | torbay
# Processing Record 10 of Set 6 | maniitsoq
# Processing Record 11 of Set 6 | san policarpo
# Processing Record 12 of Set 6 | pochutla
# Processing Record 13 of Set 6 | pingchen
# City not found. Skipping...
# Processing Record 14 of Set 6 | lata
# Processing Record 15 of Set 6 | seoul
# Processing Record 16 of Set 6 | el ocote
# Processing Record 17 of Set 6 | sabha
# Processing Record 18 of Set 6 | conde
# Processing Record 19 of Set 6 | vigrestad
# Processing Record 20 of Set 6 | ayan
# Processing Record 21 of Set 6 | castro
# Processing Record 22 of Set 6 | chikoy
# City not found. Skipping...
# Processing Record 23 of Set 6 | egyek
# Processing Record 24 of Set 6 | kukuna
# Processing Record 25 of Set 6 | touros
# Processing Record 26 of Set 6 | balaipungut
# Processing Record 27 of Set 6 | klyuchi
# Processing Record 28 of Set 6 | saint george
# Processing Record 29 of Set 6 | mareeba
# Processing Record 30 of Set 6 | peniche
# Processing Record 31 of Set 6 | nelson bay
# Processing Record 32 of Set 6 | east london
# Processing Record 33 of Set 6 | itarema
# Processing Record 34 of Set 6 | opochka
# Processing Record 35 of Set 6 | valparaiso
# Processing Record 36 of Set 6 | palmer
# Processing Record 37 of Set 6 | nizwa
# Processing Record 38 of Set 6 | victoria
# Processing Record 39 of Set 6 | yar-sale
# Processing Record 40 of Set 6 | ribeira grande
# Processing Record 41 of Set 6 | tautira
# Processing Record 42 of Set 6 | harper
# Processing Record 43 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 44 of Set 6 | roros
# Processing Record 45 of Set 6 | kabalo
# Processing Record 46 of Set 6 | ha tinh
# Processing Record 47 of Set 6 | ponta delgada
# Processing Record 48 of Set 6 | iracoubo
# Processing Record 49 of Set 6 | alice springs
# Processing Record 50 of Set 6 | pozoblanco
# Processing Record 1 of Set 7 | salalah
# Processing Record 2 of Set 7 | hoi an
# Processing Record 3 of Set 7 | visnes
# Processing Record 4 of Set 7 | provideniya
# Processing Record 5 of Set 7 | phalodi
# Processing Record 6 of Set 7 | tambul
# City not found. Skipping...
# Processing Record 7 of Set 7 | narasannapeta
# Processing Record 8 of Set 7 | baykit
# Processing Record 9 of Set 7 | ouadda
# Processing Record 10 of Set 7 | mirnyy
# Processing Record 11 of Set 7 | mount isa
# Processing Record 12 of Set 7 | kahului
# Processing Record 13 of Set 7 | benjamin constant
# Processing Record 14 of Set 7 | kuryk
# Processing Record 15 of Set 7 | arkhipo-osipovka
# Processing Record 16 of Set 7 | finschhafen
# Processing Record 17 of Set 7 | kudahuvadhoo
# Processing Record 18 of Set 7 | poum
# Processing Record 19 of Set 7 | shingu
# Processing Record 20 of Set 7 | aksarka
# Processing Record 21 of Set 7 | azare
# Processing Record 22 of Set 7 | meulaboh
# Processing Record 23 of Set 7 | bathsheba
# Processing Record 24 of Set 7 | george
# Processing Record 25 of Set 7 | lagoa
# Processing Record 26 of Set 7 | xiaoshi
# Processing Record 27 of Set 7 | monte santo de minas
# Processing Record 28 of Set 7 | ler
# Processing Record 29 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 7 | changping
# Processing Record 31 of Set 7 | pascagoula
# Processing Record 32 of Set 7 | jining
# Processing Record 33 of Set 7 | morada nova
# Processing Record 34 of Set 7 | saint-marc-des-carrieres
# Processing Record 35 of Set 7 | kushmurun
# Processing Record 36 of Set 7 | boden
# Processing Record 37 of Set 7 | necochea
# Processing Record 38 of Set 7 | matara
# Processing Record 39 of Set 7 | champerico
# Processing Record 40 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 7 | lima
# Processing Record 42 of Set 7 | waw
# Processing Record 43 of Set 7 | cedar city
# Processing Record 44 of Set 7 | bardiyah
# Processing Record 45 of Set 7 | road town
# Processing Record 46 of Set 7 | shahganj
# Processing Record 47 of Set 7 | oranjemund
# Processing Record 48 of Set 7 | cap malheureux
# Processing Record 49 of Set 7 | svetlogorsk
# Processing Record 50 of Set 7 | ostersund
# Processing Record 1 of Set 8 | mlonggo
# Processing Record 2 of Set 8 | cockburn town
# Processing Record 3 of Set 8 | digha
# Processing Record 4 of Set 8 | zabaykalsk
# Processing Record 5 of Set 8 | sur
# Processing Record 6 of Set 8 | bumba
# Processing Record 7 of Set 8 | khabary
# Processing Record 8 of Set 8 | tavda
# Processing Record 9 of Set 8 | uyuni
# Processing Record 10 of Set 8 | riyadh
# Processing Record 11 of Set 8 | thompson
# Processing Record 12 of Set 8 | leshukonskoye
# Processing Record 13 of Set 8 | russell
# Processing Record 14 of Set 8 | honiara
# Processing Record 15 of Set 8 | ariquemes
# Processing Record 16 of Set 8 | den helder
# Processing Record 17 of Set 8 | rajnagar
# Processing Record 18 of Set 8 | maldonado
# Processing Record 19 of Set 8 | nome
# Processing Record 20 of Set 8 | totness
# Processing Record 21 of Set 8 | varanasi
# Processing Record 22 of Set 8 | xining
# Processing Record 23 of Set 8 | caravelas
# Processing Record 24 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 8 | tura
# Processing Record 26 of Set 8 | saskylakh
# Processing Record 27 of Set 8 | colares
# Processing Record 28 of Set 8 | tuatapere
# Processing Record 29 of Set 8 | razole
# Processing Record 30 of Set 8 | pandan
# Processing Record 31 of Set 8 | padang
# Processing Record 32 of Set 8 | vaitape
# Processing Record 33 of Set 8 | mariental
# Processing Record 34 of Set 8 | shenkursk
# Processing Record 35 of Set 8 | stara synyava
# Processing Record 36 of Set 8 | vanimo
# Processing Record 37 of Set 8 | golspie
# Processing Record 38 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 8 | walvis bay
# Processing Record 40 of Set 8 | sorland
# Processing Record 41 of Set 8 | orlik
# Processing Record 42 of Set 8 | yetholm
# City not found. Skipping...
# Processing Record 43 of Set 8 | troitsko-pechorsk
# Processing Record 44 of Set 8 | atasu
# Processing Record 45 of Set 8 | zaozerne
# Processing Record 46 of Set 8 | ahipara
# Processing Record 47 of Set 8 | malanje
# Processing Record 48 of Set 8 | saint anthony
# Processing Record 49 of Set 8 | la ronge
# Processing Record 50 of Set 8 | ucluelet
# Processing Record 1 of Set 9 | dingle
# Processing Record 2 of Set 9 | maamba
# Processing Record 3 of Set 9 | cabedelo
# Processing Record 4 of Set 9 | kandrian
# Processing Record 5 of Set 9 | yavaros
# Processing Record 6 of Set 9 | ketchikan
# Processing Record 7 of Set 9 | gao
# Processing Record 8 of Set 9 | lhokseumawe
# Processing Record 9 of Set 9 | altamira
# Processing Record 10 of Set 9 | talgar
# Processing Record 11 of Set 9 | lokosovo
# Processing Record 12 of Set 9 | bradford
# Processing Record 13 of Set 9 | alta floresta
# Processing Record 14 of Set 9 | council bluffs
# Processing Record 15 of Set 9 | luderitz
# Processing Record 16 of Set 9 | alofi
# Processing Record 17 of Set 9 | lakatoro
# Processing Record 18 of Set 9 | kaitangata
# Processing Record 19 of Set 9 | milas
# Processing Record 20 of Set 9 | shache
# Processing Record 21 of Set 9 | saldanha
# Processing Record 22 of Set 9 | zhigansk
# Processing Record 23 of Set 9 | hofn
# Processing Record 24 of Set 9 | balykshi
# Processing Record 25 of Set 9 | noumea
# Processing Record 26 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 9 | los llanos de aridane
# Processing Record 28 of Set 9 | saint-philippe
# Processing Record 29 of Set 9 | saint-augustin
# Processing Record 30 of Set 9 | turbat
# Processing Record 31 of Set 9 | paamiut
# Processing Record 32 of Set 9 | chippewa falls
# Processing Record 33 of Set 9 | talawdi
# City not found. Skipping...
# Processing Record 34 of Set 9 | nushki
# Processing Record 35 of Set 9 | alyangula
# Processing Record 36 of Set 9 | los alamos
# Processing Record 37 of Set 9 | lazaro cardenas
# Processing Record 38 of Set 9 | margate
# Processing Record 39 of Set 9 | cap-haitien
# Processing Record 40 of Set 9 | sampit
# Processing Record 41 of Set 9 | izhma
# Processing Record 42 of Set 9 | buin
# Processing Record 43 of Set 9 | afanasyevo
# City not found. Skipping...
# Processing Record 44 of Set 9 | naugachhia
# Processing Record 45 of Set 9 | srednekolymsk
# Processing Record 46 of Set 9 | itacarambi
# Processing Record 47 of Set 9 | lavrentiya
# Processing Record 48 of Set 9 | shizunai
# Processing Record 49 of Set 9 | honolulu
# Processing Record 50 of Set 9 | erzin
# Processing Record 1 of Set 10 | huilong
# Processing Record 2 of Set 10 | mahebourg
# Processing Record 3 of Set 10 | homa bay
# Processing Record 4 of Set 10 | rajula
# Processing Record 5 of Set 10 | bom jardim
# Processing Record 6 of Set 10 | lyaskelya
# Processing Record 7 of Set 10 | impfondo
# Processing Record 8 of Set 10 | dien bien
# City not found. Skipping...
# Processing Record 9 of Set 10 | siocon
# Processing Record 10 of Set 10 | kieta
# Processing Record 11 of Set 10 | presidente epitacio
# Processing Record 12 of Set 10 | shakiso
# Processing Record 13 of Set 10 | campina verde
# Processing Record 14 of Set 10 | beloha
# Processing Record 15 of Set 10 | isla mujeres
# Processing Record 16 of Set 10 | biak
# Processing Record 17 of Set 10 | fereydun kenar
# Processing Record 18 of Set 10 | loukhi
# Processing Record 19 of Set 10 | port macquarie
# Processing Record 20 of Set 10 | spring
# Processing Record 21 of Set 10 | miajadas
# Processing Record 22 of Set 10 | saint simons
# Processing Record 23 of Set 10 | bodri
# Processing Record 24 of Set 10 | kerrville
# Processing Record 25 of Set 10 | kalulushi
# Processing Record 26 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 28 of Set 10 | manzil salim
# Processing Record 29 of Set 10 | hirado
# Processing Record 30 of Set 10 | umm lajj
# Processing Record 31 of Set 10 | le mans
# Processing Record 32 of Set 10 | pasni
# Processing Record 33 of Set 10 | aranos
# Processing Record 34 of Set 10 | cam pha
# City not found. Skipping...
# Processing Record 35 of Set 10 | gravdal
# Processing Record 36 of Set 10 | karaton
# Processing Record 37 of Set 10 | katsuura
# Processing Record 38 of Set 10 | cherepovets
# Processing Record 39 of Set 10 | egvekinot
# Processing Record 40 of Set 10 | yerofey pavlovich
# Processing Record 41 of Set 10 | ulladulla
# Processing Record 42 of Set 10 | youhao
# Processing Record 43 of Set 10 | moranbah
# Processing Record 44 of Set 10 | torrox
# Processing Record 45 of Set 10 | chunhuhub
# Processing Record 46 of Set 10 | requena
# Processing Record 47 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 10 | julio de castilhos
# Processing Record 49 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 10 | barra do garcas
# Processing Record 1 of Set 11 | panjab
# Processing Record 2 of Set 11 | khlevnoye
# Processing Record 3 of Set 11 | beringovskiy
# Processing Record 4 of Set 11 | muzhi
# Processing Record 5 of Set 11 | bharatpur
# Processing Record 6 of Set 11 | praxedis guerrero
# Processing Record 7 of Set 11 | korla
# Processing Record 8 of Set 11 | dali
# Processing Record 9 of Set 11 | hobyo
# Processing Record 10 of Set 11 | chokurdakh
# Processing Record 11 of Set 11 | tazovskiy
# Processing Record 12 of Set 11 | ismailia
# Processing Record 13 of Set 11 | kulhudhuffushi
# Processing Record 14 of Set 11 | tessalit
# Processing Record 15 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 11 | port augusta
# Processing Record 17 of Set 11 | waslala
# Processing Record 18 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 11 | tecoanapa
# Processing Record 20 of Set 11 | iroquois falls
# Processing Record 21 of Set 11 | mendoza
# Processing Record 22 of Set 11 | correia pinto
# Processing Record 23 of Set 11 | santo tomas
# Processing Record 24 of Set 11 | magadan
# Processing Record 25 of Set 11 | kholtoson
# Processing Record 26 of Set 11 | upernavik
# Processing Record 27 of Set 11 | salacgriva
# Processing Record 28 of Set 11 | mikhaylovka
# Processing Record 29 of Set 11 | rochegda
# Processing Record 30 of Set 11 | buta
# Processing Record 31 of Set 11 | formosa
# Processing Record 32 of Set 11 | santiago del estero
# Processing Record 33 of Set 11 | keflavik
# Processing Record 34 of Set 11 | novi sanzhary
# Processing Record 35 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 37 of Set 11 | axim
# Processing Record 38 of Set 11 | rio grande
# Processing Record 39 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 11 | maharajganj
# Processing Record 41 of Set 11 | pundaguitan
# Processing Record 42 of Set 11 | port-gentil
# Processing Record 43 of Set 11 | constitucion
# Processing Record 44 of Set 11 | hovd
# Processing Record 45 of Set 11 | prince rupert
# Processing Record 46 of Set 11 | channel-port aux basques
# Processing Record 47 of Set 11 | avera
# Processing Record 48 of Set 11 | port hardy
# Processing Record 49 of Set 11 | alaca
# Processing Record 50 of Set 11 | effium
# Processing Record 1 of Set 12 | roald
# Processing Record 2 of Set 12 | thunder bay
# Processing Record 3 of Set 12 | dosso
# Processing Record 4 of Set 12 | dinguiraye
# Processing Record 5 of Set 12 | vila velha
# Processing Record 6 of Set 12 | novikovo
# Processing Record 7 of Set 12 | progreso
# Processing Record 8 of Set 12 | nauta
# Processing Record 9 of Set 12 | frutal
# Processing Record 10 of Set 12 | kenitra
# Processing Record 11 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 12 | naron
# Processing Record 13 of Set 12 | pilao arcado
# City not found. Skipping...
# Processing Record 14 of Set 12 | pipri
# Processing Record 15 of Set 12 | gangapur
# Processing Record 16 of Set 12 | camana
# Processing Record 17 of Set 12 | hay river
# Processing Record 18 of Set 12 | tilichiki
# Processing Record 19 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 12 | sinnamary
# Processing Record 21 of Set 12 | temyasovo
# Processing Record 22 of Set 12 | coari
# Processing Record 23 of Set 12 | berlevag
# Processing Record 24 of Set 12 | villarrubia de los ojos
# Processing Record 25 of Set 12 | kamina
# Processing Record 26 of Set 12 | villarrica
# Processing Record 27 of Set 12 | tias
# Processing Record 28 of Set 12 | san pedro
# Processing Record 29 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 30 of Set 12 | ibotirama
# Processing Record 31 of Set 12 | koygorodok
# Processing Record 32 of Set 12 | praya
# Processing Record 33 of Set 12 | ishigaki
# Processing Record 34 of Set 12 | tijucas
# Processing Record 35 of Set 12 | soyo
# Processing Record 36 of Set 12 | broome
# Processing Record 37 of Set 12 | fort smith
# Processing Record 38 of Set 12 | roma
# Processing Record 39 of Set 12 | fort nelson
# Processing Record 40 of Set 12 | namibe
# Processing Record 41 of Set 12 | jumla
# Processing Record 42 of Set 12 | matucana
# Processing Record 43 of Set 12 | concepcion
# Processing Record 44 of Set 12 | martapura
# Processing Record 45 of Set 12 | flinders
# Processing Record 46 of Set 12 | arlit
# Processing Record 47 of Set 12 | marawi
# Processing Record 48 of Set 12 | el eden
# Processing Record 49 of Set 12 | nizhniy odes
# Processing Record 50 of Set 12 | saint-pierre
# Processing Record 1 of Set 13 | okhotsk
# Processing Record 2 of Set 13 | kekri
# Processing Record 3 of Set 13 | muisne
# Processing Record 4 of Set 13 | giyani
# Processing Record 5 of Set 13 | burns lake
# Processing Record 6 of Set 13 | boende
# Processing Record 7 of Set 13 | kloulklubed
# Processing Record 8 of Set 13 | san quintin
# Processing Record 9 of Set 13 | shakawe
# Processing Record 10 of Set 13 | ambagarh chauki
# Processing Record 11 of Set 13 | dayong
# Processing Record 12 of Set 13 | tanout
# Processing Record 13 of Set 13 | trudovoye
# Processing Record 14 of Set 13 | jalu
# Processing Record 15 of Set 13 | havre
# Processing Record 16 of Set 13 | ituango
# Processing Record 17 of Set 13 | kupang
# Processing Record 18 of Set 13 | bucerias
# Processing Record 19 of Set 13 | xianyang
# Processing Record 20 of Set 13 | altamont
# Processing Record 21 of Set 13 | hanting
# Processing Record 22 of Set 13 | fort-shevchenko
# Processing Record 23 of Set 13 | storvorde
# Processing Record 24 of Set 13 | nabire
# Processing Record 25 of Set 13 | mashhad
# Processing Record 26 of Set 13 | semirom
# Processing Record 27 of Set 13 | vao
# Processing Record 28 of Set 13 | indianola
# Processing Record 29 of Set 13 | anadyr
# Processing Record 30 of Set 13 | tahe
# Processing Record 31 of Set 13 | acapulco
# Processing Record 32 of Set 13 | uaua
# Processing Record 33 of Set 13 | caconda
# Processing Record 34 of Set 13 | kibala
# Processing Record 35 of Set 13 | phuket
# Processing Record 36 of Set 13 | beian
# Processing Record 37 of Set 13 | muscat
# Processing Record 38 of Set 13 | yarkovo
# Processing Record 39 of Set 13 | cheyenne
# Processing Record 40 of Set 13 | farap
# Processing Record 41 of Set 13 | puerto cabezas
# Processing Record 42 of Set 13 | juegang
# Processing Record 43 of Set 13 | san ramon
# Processing Record 44 of Set 13 | rio branco do sul
# Processing Record 45 of Set 13 | saraj
# Processing Record 46 of Set 13 | narsaq
# Processing Record 47 of Set 13 | damghan
# Processing Record 48 of Set 13 | barinitas
# Processing Record 49 of Set 13 | ghanzi
# Processing Record 50 of Set 13 | bourail
# Processing Record 1 of Set 14 | jilib
# Processing Record 2 of Set 14 | aklavik
# Processing Record 3 of Set 14 | dondo
# Processing Record 4 of Set 14 | omis
# Processing Record 5 of Set 14 | nemuro
# Processing Record 6 of Set 14 | pershotravneve
# Processing Record 7 of Set 14 | miri
# Processing Record 8 of Set 14 | lodwar
# Processing Record 9 of Set 14 | mazamari
# Processing Record 10 of Set 14 | tabou
# Processing Record 11 of Set 14 | broken hill
# Processing Record 12 of Set 14 | kilindoni
# Processing Record 13 of Set 14 | issoire
# Processing Record 14 of Set 14 | honggang
# Processing Record 15 of Set 14 | ixtapa
# Processing Record 16 of Set 14 | dvorichna
# Processing Record 17 of Set 14 | kisangani
# Processing Record 18 of Set 14 | carrickmacross
# Processing Record 19 of Set 14 | dataganj
# Processing Record 20 of Set 14 | mawlaik
# Processing Record 21 of Set 14 | kondinskoye
# Processing Record 22 of Set 14 | haines junction
# Processing Record 23 of Set 14 | charagua
# Processing Record 24 of Set 14 | bonthe
# Processing Record 25 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 14 | dandong
# Processing Record 27 of Set 14 | sidi bu zayd
# City not found. Skipping...
# Processing Record 28 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 29 of Set 14 | belyy yar
# Processing Record 30 of Set 14 | nouadhibou
# Processing Record 31 of Set 14 | mosquera
# Processing Record 32 of Set 14 | halifax
# Processing Record 33 of Set 14 | vila
# Processing Record 34 of Set 14 | mogocha
# Processing Record 35 of Set 14 | dawei
# Processing Record 36 of Set 14 | jinhua
# Processing Record 37 of Set 14 | grand gaube
# Processing Record 38 of Set 14 | san rafael
# Processing Record 39 of Set 14 | gat
# Processing Record 40 of Set 14 | chalons-en-champagne
# Processing Record 41 of Set 14 | mishelevka
# Processing Record 42 of Set 14 | clyde
# Processing Record 43 of Set 14 | bezhanitsy
# Processing Record 44 of Set 14 | gimli
# Processing Record 45 of Set 14 | mayumba
# Processing Record 46 of Set 14 | port keats
# Processing Record 47 of Set 14 | jijiang
# Processing Record 48 of Set 14 | usinsk
# Processing Record 49 of Set 14 | amahai
# Processing Record 50 of Set 14 | siverek
# Processing Record 1 of Set 15 | xai-xai
# Processing Record 2 of Set 15 | robertsport
# Processing Record 3 of Set 15 | brigantine
# Processing Record 4 of Set 15 | arkadak
# Processing Record 5 of Set 15 | oceanside
# Processing Record 6 of Set 15 | bestwig
# Processing Record 7 of Set 15 | chapais
# Processing Record 8 of Set 15 | lovington
# Processing Record 9 of Set 15 | krasnoselkup
# Processing Record 10 of Set 15 | aden
# Processing Record 11 of Set 15 | karamursel
# Processing Record 12 of Set 15 | nunoa
# Processing Record 13 of Set 15 | fort wellington
# Processing Record 14 of Set 15 | islamkot
# Processing Record 15 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 16 of Set 15 | yaan
# Processing Record 17 of Set 15 | zonguldak
# Processing Record 18 of Set 15 | ewa beach
# Processing Record 19 of Set 15 | shubarshi
# Processing Record 20 of Set 15 | neuquen
# Processing Record 21 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 22 of Set 15 | arcata
# Processing Record 23 of Set 15 | fallon
# Processing Record 24 of Set 15 | astipalaia
# City not found. Skipping...
# Processing Record 25 of Set 15 | esfarayen
# Processing Record 26 of Set 15 | rorvik
# Processing Record 27 of Set 15 | marzuq
# Processing Record 28 of Set 15 | itupiranga
# Processing Record 29 of Set 15 | bridlington
# Processing Record 30 of Set 15 | high prairie
# Processing Record 31 of Set 15 | bandarbeyla
# Processing Record 32 of Set 15 | port moresby
# Processing Record 33 of Set 15 | ankang
# Processing Record 34 of Set 15 | ojinaga
# Processing Record 35 of Set 15 | kihei
# Processing Record 36 of Set 15 | bagdarin
# Processing Record 37 of Set 15 | talant
# Processing Record 38 of Set 15 | iskateley
# Processing Record 39 of Set 15 | princeton
# Processing Record 40 of Set 15 | hauterive
# Processing Record 41 of Set 15 | vilyuysk
# Processing Record 42 of Set 15 | sakakah
# Processing Record 43 of Set 15 | mandalgovi
# Processing Record 44 of Set 15 | vostok
# Processing Record 45 of Set 15 | nyurba
# Processing Record 46 of Set 15 | northam
# Processing Record 47 of Set 15 | boa vista
# Processing Record 48 of Set 15 | klaksvik
# Processing Record 49 of Set 15 | bilma
# Processing Record 50 of Set 15 | ust-tsilma
# Processing Record 1 of Set 16 | khudumelapye
# Processing Record 2 of Set 16 | arak
# Processing Record 3 of Set 16 | nchelenge
# Processing Record 4 of Set 16 | taoudenni
# Processing Record 5 of Set 16 | zyryanka
# Processing Record 6 of Set 16 | grivenskaya
# Processing Record 7 of Set 16 | xintai
# Processing Record 8 of Set 16 | talnakh
# Processing Record 9 of Set 16 | malakal
# Processing Record 10 of Set 16 | lyuban
# Processing Record 11 of Set 16 | yabrud
# Processing Record 12 of Set 16 | akdepe
# Processing Record 13 of Set 16 | ilebo
# Processing Record 14 of Set 16 | cucer
# City not found. Skipping...
# Processing Record 15 of Set 16 | aiquile
# Processing Record 16 of Set 16 | metro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 712

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
new_column_order = ["City", "Country", "Lat", 
                    "Lng", "Max Temp", "Humidity", "Cloudiness",
                   "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Rapid Valley      US  44.0625 -103.1463     82.63        51
# 1         Makhachkala      RU  42.9764   47.5024     80.58        68
# 2             Rikitea      PF -23.1203 -134.9692     72.81        78
# 3            Imbituba      BR -28.2400  -48.6703     71.85        83
# 4            Zelenets      RU  61.8849   50.7489     57.45        59
# 5             Ushuaia      AR -54.8000  -68.3000     37.06        87
# 6             Hualmay      PE -11.0964  -77.6139     66.18        71
# 7  Comodoro Rivadavia      AR -45.8667  -67.5000     53.46        35
# 8              Kodiak      US  57.7900 -152.4072     52.14        94
# 9                Hall      US  34.3168  -83.7832     84.74        53
#
#    Cloudiness  Wind Speed Current Description
# 0         100        4.00     overcast clouds
# 1           0       15.73           clear sky
# 2          13       17.40          light rain
# 3         100       18.99     overcast clouds
# 4          18        2.71          few clouds
# 5         100       19.57          light rain
# 6          32       10.31    scattered clouds
# 7           0       31.07           clear sky
# 8          97        1.50     overcast clouds
# 9          88        5.35     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
